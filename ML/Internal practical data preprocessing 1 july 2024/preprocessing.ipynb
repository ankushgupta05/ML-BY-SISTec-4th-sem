# %%
import pandas as pd
import numpy as np
import seaborn as sn

# %%
df = pd.read_csv('sample data//Toyota.csv')
df
# Out:
#       Unnamed: 0  Price   Age     KM FuelType   HP  MetColor  Automatic    CC  \
# 0              0  13500  23.0  46986   Diesel   90       1.0          0  2000
# 1              1  13750  23.0  72937   Diesel   90       1.0          0  2000
# 2              2  13950  24.0  41711   Diesel   90       NaN          0  2000
# 3              3  14950  26.0  48000   Diesel   90       0.0          0  2000
# 4              4  13750  30.0  38500   Diesel   90       0.0          0  2000
# ...          ...    ...   ...    ...      ...  ...       ...        ...   ...
# 1431        1431   7500   NaN  20544   Petrol   86       1.0          0  1300
# 1432        1432  10845  72.0     ??   Petrol   86       0.0          0  1300
# 1433        1433   8500   NaN  17016   Petrol   86       0.0          0  1300
# 1434        1434   7250  70.0     ??      NaN   86       1.0          0  1300
# 1435        1435   6950  76.0      1   Petrol  110       0.0          0  1600
#
#       Doors  Weight
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0      0
# Price           0
# Age           100
# KM              0
# FuelType      100
# HP              0
# MetColor      150
# Automatic       0
# CC              0
# Doors           0
# Weight          0
# dtype: int64

# %%
df1 = df.copy()
df1
# Out:
#       Unnamed: 0  Price   Age     KM FuelType   HP  MetColor  Automatic    CC  \
# 0              0  13500  23.0  46986   Diesel   90       1.0          0  2000
# 1              1  13750  23.0  72937   Diesel   90       1.0          0  2000
# 2              2  13950  24.0  41711   Diesel   90       NaN          0  2000
# 3              3  14950  26.0  48000   Diesel   90       0.0          0  2000
# 4              4  13750  30.0  38500   Diesel   90       0.0          0  2000
# ...          ...    ...   ...    ...      ...  ...       ...        ...   ...
# 1431        1431   7500   NaN  20544   Petrol   86       1.0          0  1300
# 1432        1432  10845  72.0     ??   Petrol   86       0.0          0  1300
# 1433        1433   8500   NaN  17016   Petrol   86       0.0          0  1300
# 1434        1434   7250  70.0     ??      NaN   86       1.0          0  1300
# 1435        1435   6950  76.0      1   Petrol  110       0.0          0  1600
#
#       Doors  Weight
# ...

# %%
df1.isnull().sum()
# Out:
# Unnamed: 0      0
# Price           0
# Age           100
# KM              0
# FuelType      100
# HP              0
# MetColor      150
# Automatic       0
# CC              0
# Doors           0
# Weight          0
# dtype: int64

# %%
df1['Age'].fillna(df1['Age'].median(),inplace=True)   # remove null value from Age

# %%
df1.isnull().sum()
# Out:
# Unnamed: 0      0
# Price           0
# Age             0
# KM              0
# FuelType      100
# HP              0
# MetColor      150
# Automatic       0
# CC              0
# Doors           0
# Weight          0
# dtype: int64

# %%
import statistics as st

# %%
st.mode(df1.FuelType)
# Out:
# 'Petrol'

# %%
df1['FuelType'].fillna(st.mode(df1.FuelType),inplace=True)   # remove null value from FuelType

# %%
df1.isnull().sum()
# Out:
# Unnamed: 0      0
# Price           0
# Age             0
# KM              0
# FuelType        0
# HP              0
# MetColor      150
# Automatic       0
# CC              0
# Doors           0
# Weight          0
# dtype: int64

# %%
st.mode(df1.MetColor)
# Out:
# 1.0

# %%
df1['MetColor'].fillna(st.mode(df1.MetColor),inplace=True)   # remove null value from MetColor

# %%
df1.isnull().sum()
# Out:
# Unnamed: 0    0
# Price         0
# Age           0
# KM            0
# FuelType      0
# HP            0
# MetColor      0
# Automatic     0
# CC            0
# Doors         0
# Weight        0
# dtype: int64

# %%
df1['Doors']  =  df1['Doors'].replace(['one','three','four','five'],[1,3,4,5]).apply(lambda x : int(x))
df1
# Out:
#       Unnamed: 0  Price   Age     KM FuelType   HP  MetColor  Automatic    CC  \
# 0              0  13500  23.0  46986   Diesel   90       1.0          0  2000
# 1              1  13750  23.0  72937   Diesel   90       1.0          0  2000
# 2              2  13950  24.0  41711   Diesel   90       1.0          0  2000
# 3              3  14950  26.0  48000   Diesel   90       0.0          0  2000
# 4              4  13750  30.0  38500   Diesel   90       0.0          0  2000
# ...          ...    ...   ...    ...      ...  ...       ...        ...   ...
# 1431        1431   7500  60.0  20544   Petrol   86       1.0          0  1300
# 1432        1432  10845  72.0     ??   Petrol   86       0.0          0  1300
# 1433        1433   8500  60.0  17016   Petrol   86       0.0          0  1300
# 1434        1434   7250  70.0     ??   Petrol   86       1.0          0  1300
# 1435        1435   6950  76.0      1   Petrol  110       0.0          0  1600
#
#       Doors  Weight
# ...

# %%
df2 = df1.copy()
df2
# Out:
#       Unnamed: 0  Price   Age     KM FuelType   HP  MetColor  Automatic    CC  \
# 0              0  13500  23.0  46986   Diesel   90       1.0          0  2000
# 1              1  13750  23.0  72937   Diesel   90       1.0          0  2000
# 2              2  13950  24.0  41711   Diesel   90       1.0          0  2000
# 3              3  14950  26.0  48000   Diesel   90       0.0          0  2000
# 4              4  13750  30.0  38500   Diesel   90       0.0          0  2000
# ...          ...    ...   ...    ...      ...  ...       ...        ...   ...
# 1431        1431   7500  60.0  20544   Petrol   86       1.0          0  1300
# 1432        1432  10845  72.0     ??   Petrol   86       0.0          0  1300
# 1433        1433   8500  60.0  17016   Petrol   86       0.0          0  1300
# 1434        1434   7250  70.0     ??   Petrol   86       1.0          0  1300
# 1435        1435   6950  76.0      1   Petrol  110       0.0          0  1600
#
#       Doors  Weight
# ...

# %%
df2['HP'] = df2['HP'].replace(['?','??','???','????'],np.NaN).apply(lambda x :x)
df2
# Out:
#       Unnamed: 0  Price   Age     KM FuelType   HP  MetColor  Automatic    CC  \
# 0              0  13500  23.0  46986   Diesel   90       1.0          0  2000
# 1              1  13750  23.0  72937   Diesel   90       1.0          0  2000
# 2              2  13950  24.0  41711   Diesel   90       1.0          0  2000
# 3              3  14950  26.0  48000   Diesel   90       0.0          0  2000
# 4              4  13750  30.0  38500   Diesel   90       0.0          0  2000
# ...          ...    ...   ...    ...      ...  ...       ...        ...   ...
# 1431        1431   7500  60.0  20544   Petrol   86       1.0          0  1300
# 1432        1432  10845  72.0     ??   Petrol   86       0.0          0  1300
# 1433        1433   8500  60.0  17016   Petrol   86       0.0          0  1300
# 1434        1434   7250  70.0     ??   Petrol   86       1.0          0  1300
# 1435        1435   6950  76.0      1   Petrol  110       0.0          0  1600
#
#       Doors  Weight
# ...

# %%
df2.isnull().sum()
# Out:
# Unnamed: 0    0
# Price         0
# Age           0
# KM            0
# FuelType      0
# HP            6
# MetColor      0
# Automatic     0
# CC            0
# Doors         0
# Weight        0
# dtype: int64

# %%
df2['HP'].median()
# Out:
# 110.0

# %%
df2['HP'].fillna(df2['HP'].median(),inplace=True)   # remove null value from HP

# %%
df2.isnull().sum()
# Out:
# Unnamed: 0    0
# Price         0
# Age           0
# KM            0
# FuelType      0
# HP            0
# MetColor      0
# Automatic     0
# CC            0
# Doors         0
# Weight        0
# dtype: int64

# %%
df2['KM'] = df2['KM'].replace(['?','??','???','????'],np.NaN).apply(lambda x :x)
df2
# Out:
#       Unnamed: 0  Price   Age     KM FuelType   HP  MetColor  Automatic    CC  \
# 0              0  13500  23.0  46986   Diesel   90       1.0          0  2000
# 1              1  13750  23.0  72937   Diesel   90       1.0          0  2000
# 2              2  13950  24.0  41711   Diesel   90       1.0          0  2000
# 3              3  14950  26.0  48000   Diesel   90       0.0          0  2000
# 4              4  13750  30.0  38500   Diesel   90       0.0          0  2000
# ...          ...    ...   ...    ...      ...  ...       ...        ...   ...
# 1431        1431   7500  60.0  20544   Petrol   86       1.0          0  1300
# 1432        1432  10845  72.0    NaN   Petrol   86       0.0          0  1300
# 1433        1433   8500  60.0  17016   Petrol   86       0.0          0  1300
# 1434        1434   7250  70.0    NaN   Petrol   86       1.0          0  1300
# 1435        1435   6950  76.0      1   Petrol  110       0.0          0  1600
#
#       Doors  Weight
# ...

# %%
df2.isnull().sum()
# Out:
# Unnamed: 0     0
# Price          0
# Age            0
# KM            15
# FuelType       0
# HP             0
# MetColor       0
# Automatic      0
# CC             0
# Doors          0
# Weight         0
# dtype: int64

# %%
df2['KM'].fillna(df2['KM'].median(),inplace=True)   # remove null value from KM

# %%
df2.isnull().sum()
# Out:
# Unnamed: 0    0
# Price         0
# Age           0
# KM            0
# FuelType      0
# HP            0
# MetColor      0
# Automatic     0
# CC            0
# Doors         0
# Weight        0
# dtype: int64

# %%
import seaborn as sns
sns.boxplot(df2['Age'])
# Out:
# <Axes: >

# %%
df2[df2['Age'] < df2['Age'].mean()]
# Out:
#      Unnamed: 0  Price   Age     KM FuelType   HP  MetColor  Automatic    CC  \
# 0             0  13500  23.0  46986   Diesel   90       1.0          0  2000
# 1             1  13750  23.0  72937   Diesel   90       1.0          0  2000
# 2             2  13950  24.0  41711   Diesel   90       1.0          0  2000
# 3             3  14950  26.0  48000   Diesel   90       0.0          0  2000
# 4             4  13750  30.0  38500   Diesel   90       0.0          0  2000
# ..          ...    ...   ...    ...      ...  ...       ...        ...   ...
# 598         598  10450  48.0  15000   Petrol   97       1.0          0  1400
# 599         599  12950  50.0  10210   Petrol   97       0.0          0  1400
# 600         600  11250  47.0   5309   Petrol  110       1.0          1  1600
# 601         601   7500  50.0      1   Diesel   90       1.0          0  2000
# 602         602   8950  52.0  31000   Petrol   97       1.0          0  1398
#
#      Doors  Weight
# 0        3    1165
# ...

# %%
df2.Age.mean()
# Out:
# 55.97353760445682

# %%
df2.Age.plot(kind="box", vert= False)
# Out:
# <Axes: >

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.subplot(2,2,1)
sns.histplot(df1['Weight'], kde=True)
plt.subplot(2,2,2)
sns.histplot(df1['Age'], kde=True)
plt.subplot(2,2,3)
sns.histplot(df1['HP'], kde=True)
plt.subplot(2,2,4)
sns.histplot(df1['Doors'], kde=True)
# Out:
# <Axes: xlabel='Doors', ylabel='Count'>

# %%
# 1) logarithmic transformation first method 
plt.subplot(2,2,1)
df2['Age'] = np.log(df2['Age'])
print(sns.histplot(df2['Age'],kde=True))


# 2) receiprocal methods
plt.subplot(2,2,2)
df2['Age'] = 1/df.Age
print(sns.histplot(df['Age'],kde=True))


# 3) square root transformation 

plt.subplot(2,2,3)
df['Age'] = df.Age **(1/2)
print(sns.histplot(df['Age'],kde=True))



# 4) exponential transformation

plt.subplot(2,2,4)
df['Age'] = df.Age **(1/1.2)
print(sns.histplot(df['Age'],kde=True))
# Out:
# Axes(0.125,0.53;0.352273x0.35)
# Axes(0.547727,0.53;0.352273x0.35)
# Axes(0.125,0.11;0.352273x0.35)
# Axes(0.547727,0.11;0.352273x0.35)

# %%
# # 3) square root transformation 

# plt.subplot(2,2,1)
# df['Age'] = df.Age **(1/2)
# print(sns.histplot(df['Age'],kde=True))



# # 4) exponential transformation

# plt.subplot(2,2,2)
# df['Age'] = df.Age **(1/1.2)
# print(sns.histplot(df['Age'],kde=True))

# %%
df2.isnull().sum()
# Out:
# Unnamed: 0       0
# Price            0
# Age              0
# KM               0
# FuelType         0
# HP               0
# MetColor         0
# Automatic        0
# CC               0
# Doors            0
# Weight        1436
# dtype: int64
